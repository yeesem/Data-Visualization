# %% [markdown]
# <a href="https://colab.research.google.com/github/yeesem2002/Data-Visualization/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#Functional
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
plt.show()

# %%
#Multiplot
#Number of rows,number of col,numbering
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#Object Oriented

#Create a figure
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.15,0.5,0.4,0.3])

axes1.plot(x,y)
axes2.plot(y,x)

axes1.set_title('LARGER PLOT')
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
#Subplot by using Object Oriented Method
fig,axes = plt.subplots(nrows=1,ncols=2)
plt.tight_layout()
#axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 1,ncols = 2)

for current_ax in axes:
   current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 1,ncols = 2)

axes[0].plot(x,y)
axes[0].set_title("First Plot")

axes[1].plot(y,x)
axes[1].set_title("Second Plot")

#Avoid graphs overlapping
plt.tight_layout()

# %%
fig = plt.figure(figsize=(3,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 1,ncols = 2,figsize = (8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %%
fig

# %%
#.png
fig.savefig('my_picture.jpg',dpi = 200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

#label is for the reference of legend function
ax.plot(x,x**2,label = 'X Square')
ax.plot(x,x**3,label = 'X Cubed')

#loc the location of the legend box
#loc=(0.1,0.1)
#ax.legend(loc = 0)
ax.legend(loc = (0.1,0.1))


ax.set_title('Title')
ax.set_ylabel('Y')
ax.set_xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

#Can set the colour by using the RGB Hex code for more options
#alpha - set the transparency of the line
#Type lw also works to replace linewidth
#ls = linestyle
ax.plot(x,y,color = 'blue',linewidth=2,alpha = 0.5,linestyle=':',marker = 'o',markersize = 5
        ,markerfacecolor = 'yellow',markeredgewidth = 2,markeredgecolor = 'black')

# %%
fig =plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color = 'blue',lw=2,alpha = 0.5,ls = '--')

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %%
plt.scatter(x,y)

# %%
from random import sample

data = sample(range(1,1000),100)
plt.hist(data,color = 'blue')
# Out:
# (array([ 8., 10., 10., 10., 10., 13., 15., 10.,  8.,  6.]),
#  array([  4. , 102.3, 200.6, 298.9, 397.2, 495.5, 593.8, 692.1, 790.4,
#         888.7, 987. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]

#Rectangular boxplot
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7881ad6a6710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7881acdc78e0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7881adf913c0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7881acdc55a0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7881acdc7910>,
# ...
#  'means': []}

# %% [markdown]
# # **Matplotlib Exercise**

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig = plt.figure()

axes = fig.add_axes([0,0,1,1])
axes.plot(x,y)
axes.set_title('title')

axes.set_xlabel('x')
axes.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.2,.5,.2,.2])

#plt.tight_layout()

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.2,.5,.2,.2])

axes1.plot(x,y,color = 'red')
axes2.plot(x,y,color = 'red')

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.4,.4])

# %%
fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.1,0.5,.4,.4])

ax1.plot(x,z)
ax1.set_xlabel("x")
ax1.set_ylabel("z")

ax2.plot(x,y)
ax2.set_title('zoom')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
# Out:
# (30.0, 50.0)

# %%
fig,axes = plt.subplots(nrows = 1,ncols = 2)

# %%
fig,axes = plt.subplots(nrows = 1,ncols = 2)

axes[0].plot(x,y,lw = 3,ls = '--',color = 'blue')
axes[1].plot(x,z,lw = 3,ls = '-',color = 'red')

plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows = 1,ncols = 2,figsize = (12,2))

axes[0].plot(x,y,lw = 3,ls = '--',color = 'blue')
axes[1].plot(x,z,lw = 3,ls = '-',color = 'red')

plt.tight_layout()
